# %% [markdown]
# # <snap  style="color:red"> Simple deep learning model </snap>

# %%
# Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf

# Importing dataset
df = sns.load_dataset("tips")
df.head()

# Data preprocessing
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
le = LabelEncoder()
df["sex"] = le.fit_transform(df["sex"])
df["smoker"] = le.fit_transform(df["smoker"])
df["day"] = le.fit_transform(df["day"])
df["time"] = le.fit_transform(df["time"])


# Defining X and y
X = df.drop("tip", axis = 1)
y = df["tip"]

scaler =  MinMaxScaler()
X_scaled = scaler.fit_transform(X)

## train test split the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y , test_size = 0.2, random_state=42)

# %%
# Creating the Model
model = tf.keras.Sequential([
        tf.keras.layers.Dense(32, input_shape = [X_train.shape[1]]), # input layer
        tf.keras.layers.Dense(16, activation='relu'), # hidden layer
        tf.keras.layers.Dense(1)
    ])

# Compile the Model
model.compile(
    optimizer = "adam",
    loss = "mean_squared_error",
    metrics = 'accuracy'
    )

# train the model
model.fit(X_train, y_train, epochs = 50, batch_size = 32, verbose = 1)

#evaluate the model
loss = model.evaluate(X_test, y_test)
print("test loss = ", loss)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 2s 4ms/step - loss: 13.0522 - accuracy: 0.0000e+00
# Epoch 2/50
# 7/7 [==============================] - 0s 6ms/step - loss: 12.1604 - accuracy: 0.0000e+00
# Epoch 3/50
# 7/7 [==============================] - 0s 6ms/step - loss: 11.5240 - accuracy: 0.0000e+00
# Epoch 4/50
# 7/7 [==============================] - 0s 16ms/step - loss: 11.0689 - accuracy: 0.0000e+00
# Epoch 5/50
# 7/7 [==============================] - 0s 6ms/step - loss: 10.6050 - accuracy: 0.0000e+00
# Epoch 6/50
# 7/7 [==============================] - 0s 8ms/step - loss: 10.1365 - accuracy: 0.0000e+00
# Epoch 7/50
# 7/7 [==============================] - 0s 6ms/step - loss: 9.5891 - accuracy: 0.0051
# Epoch 8/50
# 7/7 [==============================] - 0s 10ms/step - loss: 8.9294 - accuracy: 0.0103
# Epoch 9/50
# 7/7 [==============================] - 0s 6ms/step - loss: 8.1467 - accuracy: 0.0103
# Epoch 10/50
# 7/7 [==============================] - 0s 6ms/step - loss: 7.3293 - accuracy: 0.0103
# Epoch 11/50
# 7/7 [==============================] - 0s 7ms/step - loss: 6.3535 - accuracy: 0.0154
# Epoch 12/50
# 7/7 [==============================] - 0s 5ms/step - loss: 5.3413 - accuracy: 0.0154
# Epoch 13/50
# 7/7 [==============================] - 0s 6ms/step - loss: 4.3918 - accuracy: 0.0154
# Epoch 14/50
# 7/7 [==============================] - 0s 5ms/step - loss: 3.5841 - accuracy: 0.0154
# Epoch 15/50
# 7/7 [==============================] - 0s 13ms/step - loss: 3.0095 - accuracy: 0.0154
# Epoch 16/50
# 7/7 [==============================] - 0s 6ms/step - loss: 2.6605 - accuracy: 0.0154
# Epoch 17/50
# 7/7 [==============================] - 0s 6ms/step - loss: 2.4838 - accuracy: 0.0154
# Epoch 18/50
# 7/7 [==============================] - 0s 8ms/step - loss: 2.4060 - accuracy: 0.0154
# Epoch 19/50
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2990 - accuracy: 0.0154
# Epoch 20/50
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2141 - accuracy: 0.0154
# Epoch 21/50
# 7/7 [==============================] - 0s 5ms/step - loss: 2.1386 - accuracy: 0.0154
# Epoch 22/50
# 7/7 [==============================] - 0s 6ms/step - loss: 2.0734 - accuracy: 0.0154
# Epoch 23/50
# 7/7 [==============================] - 0s 7ms/step - loss: 2.0120 - accuracy: 0.0154
# Epoch 24/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.9526 - accuracy: 0.0154
# Epoch 25/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.8928 - accuracy: 0.0154
# Epoch 26/50
# 7/7 [==============================] - 0s 7ms/step - loss: 1.8468 - accuracy: 0.0154
# Epoch 27/50
# 7/7 [==============================] - 0s 6ms/step - loss: 1.8011 - accuracy: 0.0154
# Epoch 28/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.7658 - accuracy: 0.0154
# Epoch 29/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.7233 - accuracy: 0.0154
# Epoch 30/50
# 7/7 [==============================] - 0s 7ms/step - loss: 1.6913 - accuracy: 0.0154
# Epoch 31/50
# 7/7 [==============================] - 0s 6ms/step - loss: 1.6632 - accuracy: 0.0154
# Epoch 32/50
# 7/7 [==============================] - 0s 7ms/step - loss: 1.6400 - accuracy: 0.0154
# Epoch 33/50
# 7/7 [==============================] - 0s 7ms/step - loss: 1.6191 - accuracy: 0.0154
# Epoch 34/50
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5928 - accuracy: 0.0154
# Epoch 35/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.5661 - accuracy: 0.0154
# Epoch 36/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.5489 - accuracy: 0.0154
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.5296 - accuracy: 0.0154
# Epoch 38/50
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5165 - accuracy: 0.0154
# Epoch 39/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4958 - accuracy: 0.0154
# Epoch 40/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4742 - accuracy: 0.0154
# Epoch 41/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4547 - accuracy: 0.0154
# Epoch 42/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4467 - accuracy: 0.0154
# Epoch 43/50
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4355 - accuracy: 0.0154
# Epoch 44/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4129 - accuracy: 0.0154
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.4002 - accuracy: 0.0154
# Epoch 46/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3838 - accuracy: 0.0154
# Epoch 47/50
# 7/7 [==============================] - 0s 7ms/step - loss: 1.3696 - accuracy: 0.0154
# Epoch 48/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3930 - accuracy: 0.0154
# Epoch 49/50
# 7/7 [==============================] - 0s 15ms/step - loss: 1.3761 - accuracy: 0.0154
# Epoch 50/50
# 7/7 [==============================] - 0s 7ms/step - loss: 1.3386 - accuracy: 0.0154
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9120 - accuracy: 0.0204
# test loss =  [0.912019670009613, 0.020408162847161293]
